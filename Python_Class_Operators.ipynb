# %% [markdown]
# <a href="https://colab.research.google.com/github/balamurali9492/Python_class1/blob/main/Python_Class_Operators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Arithmetic Operators

# %%
#Write a program to perform addition, subtraction, multiplication, division, floor division, modulus, and exponentiation on two numbers.
print("add=",5+2)
print("sub=",5-2)
print("mult=",5*2)
print("div=",5/2)
print("floor=",5//2)
print("mod=",5%2)
print("expo=",5**2)
# Out:
# add= 7
# sub= 3
# mult= 10
# div= 2.5
# floor= 2
# mod= 1
# expo= 25

# %%
#Swap two numbers without using a third variable.
a=2
b=3
a,b=b,a
print(a)
print(b)
# Out:
# 3
# 2

# %%
#Find whether a number is even or odd using the modulus operator.
num=6
if num % 2 ==0:
  print("Even Number")
else:
  print("odd number")
# Out:
# Even Number

# %%
#Reverse a three-digit number using arithmetic operators.
num=523
a= num % 10
b=(num // 10) %10
c=num // 100
reverse = a * 100 + b * 10 + c
print(reverse)
# Out:
# 325

# %%
#Find the last digit and first digit of a given number.
num=325
a= num // 100
b=num % 10
print(a)
print(b)
# Out:
# 3
# 5

# %% [markdown]
# Assignment Operators

# %%
#Demonstrate all assignment operators (=, +=, -=, *=, /=, //=, %= and **=) on a variable.
x=10
print(x)
x+=22
print(x)
x-=20
print(x)
x*=5
print(x)
x/=25
print(x)
x//=20
print(x)
x%=5
print(x)
x**=25
print(x)
# Out:
# 10
# 32
# 12
# 60
# 2.4
# 0.0
# 0.0
# 0.0

# %%
#Update a bank account balance using compound assignment operators.

money = 10000
print(money)

# Deposit money
money += 5000
print("After deposit =",money)

# Withdraw money
money -= 2000
print("After withdrawal =",money)

# Add interest
money *= 1.05
print("After interest =",money)

# Divide balance (example)
money /= 2
print("After division =",money)
# Out:
# 10000
# After deposit = 15000
# After withdrawal = 13000
# After interest = 13650.0
# After division = 6825.0

# %%
#Calculate the total marks using += inside a loop.
marks=[70,80,90,65,57,78]
total=0
for i in marks:
  total+=i
print(total)
# Out:
# 440

# %% [markdown]
# Comparison Operators

# %%
#Compare two numbers and print the larger number.
a=34
b=30
if a>b:
  print("large number",a)
else:
  print("large number",b)
# Out:
# large number 34

# %%
#Check whether three numbers are equal.
a=10
b=10
c=15
if a==b==c:
  print("Numbers are equal")
else:
  print("not equal")
# Out:
# not equal

# %%
#Find the largest among three numbers using comparison operators.
a=9
b=5
c=15
if a>=b and a>=c:
  print("large number=",a)
elif b>=a and b>=c:
  print("large number=",b)
else:
  print("large number=",c)
# Out:
# large number= 15

# %%
#Check whether a student is eligible to vote based on age.
age=17

if age >= 18:
  print("eligible for vote")
else:
  print("not eligible for vote")
# Out:
# not eligible for vote

# %% [markdown]
# Logical Operators

# %%
#Check if a person is eligible for a loan (age > 21 AND salary > 30000).
age=21
salary=30000
if age > 21 and salary > 30000:
  print("eligible for loan")
else:
  print("Not eligible for loan")
# Out:
# Not eligible for loan

# %%
#Check if a number lies between 10 and 100 using logical operators.
num=10
if num >=10 and num <=100:
  print("number lies between 10 and 100")
else:
  print("number is not between 10 and 100")
# Out:
# number lies between 10 and 100

# %%
#Validate username and password using logical operators.
username="admin"
password=1234
if username=="admin" and password==1234:
  print("login successfull")
else:
  print("Failed")
# Out:
# login successfull

# %%
#Determine whether a year is a leap year using logical conditions.
leapyear=2028
if (leapyear % 100 ==0) or (leapyear % 100!=0 and leapyear %4 ==0):
  print("leapyear")
else:
  print("Not leapyear")
# Out:
# leapyear

# %% [markdown]
# Bitwise Operators

# %%
#Find the bitwise AND, OR, XOR of two numbers.
print(10 & 20)
print(10 | 20)
print(10 ^ 20)
# Out:
# 0
# 30
# 30

# %%
#Perform left shift and right shift operations.
print(10 << 2)
print(10 >> 2)
# Out:
# 40
# 2

# %%
#Check whether a number is even using a bitwise operator.
a=5
if a & 1 == 0:
  print("even")
else:
  print("odd")
# Out:
# odd

# %%
#Swap two numbers using the XOR operator.
a=3
b=2
a=a^b
b=a^b
a=a^b

print(a)
print(b)
# Out:
# 2
# 3

# %%
#Count how many bits are set to 1 in a number using bitwise operations.
a=7
print(a.bit_count())
# Out:
# 3

# %% [markdown]
# Identity Operators

# %%
#Demonstrate the difference between is and ==.
a=[1,2,3]
b=[1,2,3]
print(a==b)   # It will check the values is same or not
print(a is b) # It will check the both variables refer to the same object in memory
# Out:
# True
# False

# %%
#Check whether two variables refer to the same list object.
list1=[1,2,3]
list2=[1,2,3]
list3=list2
print(list1 is list2)
print(list2 is list3)
# Out:
# False
# True

# %%
#Show the behavior of is not with integers and lists.
list1=[1,2,3]
list2=[1,2,3]
list3=list2
print(list1 is not list2)
print(list2 is not list3)
# Out:
# True
# False

# %% [markdown]
# Membership Operators

# %%
#Check whether a character exists in a string.
string="python"
if "P" in string:
  print("character is tere")
else:
  print("character is not tere")

print("t" in string)
print("P" in string)
# Out:
# character is not tere
# True
# False

# %%
#Check whether a number exists in a list.
list=[1,2,3,4,5]
if 6 in list:
  print("number exists")
else:
  print("number not exists")


print(2 in list)
print(6 in list)
# Out:
# number not exists
# True
# False

# %%
#Count how many vowels in a string belong to a predefined vowel list using in.
string="edukron"
vowels="aeiouAEIOU"
count=0
for i in string:
  if i in vowels:
    count+=1
print(count)
# Out:
# 3

# %% [markdown]
# Mixed Operator Programs

# %%
#Build a simple calculator using arithmetic and comparison operators.
a=5
b=3
print("add=",a+b)
print("sub=",a-b)
print("mult=",a*b)
print("div=",a/b)
print(a<b)
print(a>b)
print(a==b)
# Out:
# add= 8
# sub= 2
# mult= 15
# div= 1.6666666666666667
# False
# True
# False

# %%
#Create a grading system using comparison and logical operators.
marks=73
if marks >= 90 and marks <= 100:
  print("Grade A")
elif marks >= 80 and marks <= 90:
  print("Grade B")
elif marks >= 70 and marks <= 80:
  print("Grade C")
elif marks >= 60 and marks <= 70:
  print("Grade D")
elif marks >= 50 and marks <= 60:
  print("Grade E")
elif marks >= 0 and marks <= 50:
  print("Grade F")
else:
  print("invalid marks")
# Out:
# Grade C

# %%
#Build a menu-driven calculator that uses arithmetic, comparison, logical, assignment, membership, identity, and bitwise operators wherever applicable.
a=5
b=3
print("1.Arithmetic")
print("2.Comparison")
print("3.Logical")
print("4.Assignment")
print("5.Membership")
print("6.Identity")
print("7.Bitwise")

cal=int(input("enter the number"))
if cal==1:
  print("add=",a+b)
  print("sub=",a-b)
  print("mult=",a*b)
  print("div=",a/b)
elif cal==2:
  print(a > b)
  print(a < b)
  print(a == b)
elif cal == 3:
  print(a > 0 and b > 0)
  print(a > 0 or b > 0)
  print(not(a > b))
elif cal==4:
  a+=b
  print(a)
elif cal==5:
  l = [1, 20, 3, 40, 50]
  print(a in l)
  print(b in l)
elif cal == 6:
  x = [1, 2, 3]
  y = x
  print(x is y)
  print(x is not y)
elif cal == 7:
    print("AND =", a & b)
    print("OR =", a | b)
    print("XOR =", a ^ b)
else:
    print("Invalid choice")
# Out:
# 1.Arithmetic
# 2.Comparison
# 3.Logical
# 4.Assignment
# 5.Membership
# 6.Identity
# 7.Bitwise
# enter the number7
# AND = 1
# OR = 7
# XOR = 6
